# %%
# Configuración de entorno y logging
import os
import sys
import logging

# Configurar logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# Agregar src/ al path si no está
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
# Importar funciones y cargar archivo csv
from src.data.load_data import cargar_datos
from src.data.exploracion_inicial import diagnostico_inicial

# Ruta del archivo CSV
csv_path = "../data/raw/vehiculos.csv"

# Cargar datos
df = cargar_datos(csv_path)
# Out:
# 2025-07-01 08:47:01,008 - INFO - Datos cargados correctamente desde: ../data/raw/vehiculos.csv

# %%
# Análisis exploratorio de la data
from src.data.exploracion_inicial import diagnostico_inicial

diagnostico_inicial(df, save_dir="../outputs/01_diagnostico")
# Out:
# 2025-07-01 08:47:01,079 - INFO - Resumen general del dataset:
# 2025-07-01 08:47:01,080 - INFO - Filas: 36791, Columnas: 19
# 2025-07-01 08:47:01,083 - INFO - Columnas:
# fabricante               object
# modelo                   object
# year                      int64
# desplazamiento          float64
# cilindros               float64
# transmision              object
# traccion                 object
# clase                    object
# combustible              object
# consumo                   int64
# co2                     float64
# clase_tipo               object
# traccion_tipo            object
# transmision_tipo         object
# combustible_tipo         object
# tamano_motor_tipo        object
# consumo_tipo             object
# co2_tipo                 object
# consumo_litros_milla    float64
# dtype: object
# 2025-07-01 08:47:01,121 - INFO - Resumen estadístico:
#            year  desplazamiento  cilindros   consumo       co2  \
# ...
